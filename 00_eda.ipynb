# %% [markdown]
# # 1. Preliminary

# %% [markdown]
# ## 1.1 Context

# %% [markdown]
# * We will analyze a very well known NLP dataset: tweets from disaster
#
#
# * It is a Kaggle competition, which offers a simple but good level textual dataset to be able to make its weapons in NLP
#
#
# * The dataset is here [https://www.kaggle.com/competitions/nlp-getting-started/data]
#
#
# * Please use the **train** dataset
#
#
# * In this 1st part we are just play and discover with this dataset

# %% [markdown]
# ## 1.2 Requirements

# %% [markdown]
# You have to install  :
#
# * pandas
# * numpy
# * matplotlib
# * seaborn

# %% [markdown]
# ## 1.3 Imports

# %%
import os, sys, time

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.4 Graphics and options

# %%
sns.set()

# %% [markdown]
# ## 1.5 Loading data

# %%
# !tree
# Out:
# .
# ├── 00_text_analysis.ipynb
# ├── 00_text_analysis_LIVE.ipynb
# ├── 01_text.ipynb
# ├── 02_modelize.ipynb
# ├── data
# │   ├── cleaned
# │   │   ├── df_cleaned.csv
# │   │   ├── df.csv
# │   │   ├── finad_df.csv
# │   │   ├── final_df.csv
# │   │   ├── min_5_words.csv
# │   │   └── unique_words.csv
# │   └── source
# │       ├── superheroes_nlp_dataset.csv
# │       └── twit_from_disaster_train.csv
# ├── env
# │   ├── bin
# │   │   ├── activate
# │   │   ├── activate.csh
# │   │   ├── activate.fish
# │   │   ├── Activate.ps1
# │   │   ├── easy_install
# │   │   ├── easy_install-3.8
# │   │   ├── f2py
# │   │   ├── f2py3
# │   │   ├── f2py3.8
# │   │   ├── fonttools
# │   │   ├── get_objgraph
# │   │   ├── ipython
# │   │   ├── ipython3
# │   │   ├── jsonschema
# │   │   ├── jupyter
# │   │   ├── jupyter-bundlerextension
# │   │   ├── jupyter-console
# │   │   ├── jupyter-dejavu
# │   │   ├── jupyter-execute
# │   │   ├── jupyter-kernel
# │   │   ├── jupyter-kernelspec
# │   │   ├── jupyter-migrate
# │   │   ├── jupyter-nbconvert
# │   │   ├── jupyter-nbextension
# │   │   ├── jupyter-notebook
# │   │   ├── jupyter-qtconsole
# │   │   ├── jupyter-run
# │   │   ├── jupyter-serverextension
# │   │   ├── jupyter-troubleshoot
# │   │   ├── jupyter-trust
# │   │   ├── nltk
# │   │   ├── normalizer
# │   │   ├── pathy
# │   │   ├── pip
# │   │   ├── pip3
# │   │   ├── pip3.8
# │   │   ├── pyftmerge
# │   │   ├── pyftsubset
# │   │   ├── pygmentize
# │   │   ├── python -> python3
# │   │   ├── python3 -> /home/alex/ENV/bin/python3
# │   │   ├── qtpy
# │   │   ├── send2trash
# │   │   ├── spacy
# │   │   ├── tqdm
# │   │   ├── ttx
# │   │   ├── undill
# │   │   └── wordcloud_cli
# │   ├── etc
# │   │   └── jupyter
# │   │       └── nbconfig
# │   │           └── notebook.d
# │   │               ├── jupyterlab-plotly.json
# │   │               └── widgetsnbextension.json
# │   ├── include
# │   ├── lib
# │   │   └── python3.8
# │   │       └── site-packages
# │   │           ├── argon2
# │   │           │   ├── exceptions.py
# │   │           │   ├── __init__.py
# │   │           │   ├── _legacy.py
# │   │           │   ├── low_level.py
# │   │           │   ├── __main__.py
# │   │           │   ├── _password_hasher.py
# │   │           │   ├── profiles.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── exceptions.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── _legacy.cpython-38.pyc
# │   │           │   │   ├── low_level.cpython-38.pyc
# │   │           │   │   ├── __main__.cpython-38.pyc
# │   │           │   │   ├── _password_hasher.cpython-38.pyc
# │   │           │   │   ├── profiles.cpython-38.pyc
# │   │           │   │   ├── _typing.cpython-38.pyc
# │   │           │   │   └── _utils.cpython-38.pyc
# │   │           │   ├── py.typed
# │   │           │   ├── _typing.py
# │   │           │   └── _utils.py
# │   │           ├── argon2_cffi-21.3.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   └── WHEEL
# │   │           ├── _argon2_cffi_bindings
# │   │           │   ├── _ffi.abi3.so
# │   │           │   ├── _ffi_build.py
# │   │           │   ├── __init__.py
# │   │           │   └── __pycache__
# │   │           │       ├── _ffi_build.cpython-38.pyc
# │   │           │       └── __init__.cpython-38.pyc
# │   │           ├── argon2_cffi_bindings-21.2.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── asttokens
# │   │           │   ├── asttokens.py
# │   │           │   ├── __init__.py
# │   │           │   ├── line_numbers.py
# │   │           │   ├── mark_tokens.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── asttokens.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── line_numbers.cpython-38.pyc
# │   │           │   │   ├── mark_tokens.cpython-38.pyc
# │   │           │   │   ├── util.cpython-38.pyc
# │   │           │   │   └── version.cpython-38.pyc
# │   │           │   ├── util.py
# │   │           │   └── version.py
# │   │           ├── asttokens-2.0.5.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── attr
# │   │           │   ├── _cmp.py
# │   │           │   ├── _cmp.pyi
# │   │           │   ├── _compat.py
# │   │           │   ├── _config.py
# │   │           │   ├── converters.py
# │   │           │   ├── converters.pyi
# │   │           │   ├── exceptions.py
# │   │           │   ├── exceptions.pyi
# │   │           │   ├── filters.py
# │   │           │   ├── filters.pyi
# │   │           │   ├── _funcs.py
# │   │           │   ├── __init__.py
# │   │           │   ├── __init__.pyi
# │   │           │   ├── _make.py
# │   │           │   ├── _next_gen.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── _cmp.cpython-38.pyc
# │   │           │   │   ├── _compat.cpython-38.pyc
# │   │           │   │   ├── _config.cpython-38.pyc
# │   │           │   │   ├── converters.cpython-38.pyc
# │   │           │   │   ├── exceptions.cpython-38.pyc
# │   │           │   │   ├── filters.cpython-38.pyc
# │   │           │   │   ├── _funcs.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── _make.cpython-38.pyc
# │   │           │   │   ├── _next_gen.cpython-38.pyc
# │   │           │   │   ├── setters.cpython-38.pyc
# │   │           │   │   ├── validators.cpython-38.pyc
# │   │           │   │   └── _version_info.cpython-38.pyc
# │   │           │   ├── py.typed
# │   │           │   ├── setters.py
# │   │           │   ├── setters.pyi
# │   │           │   ├── validators.py
# │   │           │   ├── validators.pyi
# │   │           │   ├── _version_info.py
# │   │           │   └── _version_info.pyi
# │   │           ├── attrs
# │   │           │   ├── converters.py
# │   │           │   ├── exceptions.py
# │   │           │   ├── filters.py
# │   │           │   ├── __init__.py
# │   │           │   ├── __init__.pyi
# │   │           │   ├── __pycache__
# │   │           │   │   ├── converters.cpython-38.pyc
# │   │           │   │   ├── exceptions.cpython-38.pyc
# │   │           │   │   ├── filters.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── setters.cpython-38.pyc
# │   │           │   │   └── validators.cpython-38.pyc
# │   │           │   ├── py.typed
# │   │           │   ├── setters.py
# │   │           │   └── validators.py
# │   │           ├── attrs-21.4.0.dist-info
# │   │           │   ├── AUTHORS.rst
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── backcall
# │   │           │   ├── backcall.py
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── backcall.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   └── _signatures.cpython-38.pyc
# │   │           │   └── _signatures.py
# │   │           ├── backcall-0.2.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   └── WHEEL
# │   │           ├── beautifulsoup4-4.11.1.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── bleach
# │   │           │   ├── callbacks.py
# │   │           │   ├── css_sanitizer.py
# │   │           │   ├── html5lib_shim.py
# │   │           │   ├── __init__.py
# │   │           │   ├── linkifier.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── callbacks.cpython-38.pyc
# │   │           │   │   ├── css_sanitizer.cpython-38.pyc
# │   │           │   │   ├── html5lib_shim.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── linkifier.cpython-38.pyc
# │   │           │   │   └── sanitizer.cpython-38.pyc
# │   │           │   ├── sanitizer.py
# │   │           │   └── _vendor
# │   │           │       ├── html5lib
# │   │           │       │   ├── constants.py
# │   │           │       │   ├── filters
# │   │           │       │   │   ├── alphabeticalattributes.py
# │   │           │       │   │   ├── base.py
# │   │           │       │   │   ├── __init__.py
# │   │           │       │   │   ├── inject_meta_charset.py
# │   │           │       │   │   ├── lint.py
# │   │           │       │   │   ├── optionaltags.py
# │   │           │       │   │   ├── __pycache__
# │   │           │       │   │   │   ├── alphabeticalattributes.cpython-38.pyc
# │   │           │       │   │   │   ├── base.cpython-38.pyc
# │   │           │       │   │   │   ├── __init__.cpython-38.pyc
# │   │           │       │   │   │   ├── inject_meta_charset.cpython-38.pyc
# │   │           │       │   │   │   ├── lint.cpython-38.pyc
# │   │           │       │   │   │   ├── optionaltags.cpython-38.pyc
# │   │           │       │   │   │   ├── sanitizer.cpython-38.pyc
# │   │           │       │   │   │   └── whitespace.cpython-38.pyc
# │   │           │       │   │   ├── sanitizer.py
# │   │           │       │   │   └── whitespace.py
# │   │           │       │   ├── html5parser.py
# │   │           │       │   ├── _ihatexml.py
# │   │           │       │   ├── __init__.py
# │   │           │       │   ├── _inputstream.py
# │   │           │       │   ├── __pycache__
# │   │           │       │   │   ├── constants.cpython-38.pyc
# │   │           │       │   │   ├── html5parser.cpython-38.pyc
# │   │           │       │   │   ├── _ihatexml.cpython-38.pyc
# │   │           │       │   │   ├── __init__.cpython-38.pyc
# │   │           │       │   │   ├── _inputstream.cpython-38.pyc
# │   │           │       │   │   ├── serializer.cpython-38.pyc
# │   │           │       │   │   ├── _tokenizer.cpython-38.pyc
# │   │           │       │   │   └── _utils.cpython-38.pyc
# │   │           │       │   ├── serializer.py
# │   │           │       │   ├── _tokenizer.py
# │   │           │       │   ├── treeadapters
# │   │           │       │   │   ├── genshi.py
# │   │           │       │   │   ├── __init__.py
# │   │           │       │   │   ├── __pycache__
# │   │           │       │   │   │   ├── genshi.cpython-38.pyc
# │   │           │       │   │   │   ├── __init__.cpython-38.pyc
# │   │           │       │   │   │   └── sax.cpython-38.pyc
# │   │           │       │   │   └── sax.py
# │   │           │       │   ├── treebuilders
# │   │           │       │   │   ├── base.py
# │   │           │       │   │   ├── dom.py
# │   │           │       │   │   ├── etree_lxml.py
# │   │           │       │   │   ├── etree.py
# │   │           │       │   │   ├── __init__.py
# │   │           │       │   │   └── __pycache__
# │   │           │       │   │       ├── base.cpython-38.pyc
# │   │           │       │   │       ├── dom.cpython-38.pyc
# │   │           │       │   │       ├── etree.cpython-38.pyc
# │   │           │       │   │       ├── etree_lxml.cpython-38.pyc
# │   │           │       │   │       └── __init__.cpython-38.pyc
# │   │           │       │   ├── treewalkers
# │   │           │       │   │   ├── base.py
# │   │           │       │   │   ├── dom.py
# │   │           │       │   │   ├── etree_lxml.py
# │   │           │       │   │   ├── etree.py
# │   │           │       │   │   ├── genshi.py
# │   │           │       │   │   ├── __init__.py
# │   │           │       │   │   └── __pycache__
# │   │           │       │   │       ├── base.cpython-38.pyc
# │   │           │       │   │       ├── dom.cpython-38.pyc
# │   │           │       │   │       ├── etree.cpython-38.pyc
# │   │           │       │   │       ├── etree_lxml.cpython-38.pyc
# │   │           │       │   │       ├── genshi.cpython-38.pyc
# │   │           │       │   │       └── __init__.cpython-38.pyc
# │   │           │       │   ├── _trie
# │   │           │       │   │   ├── _base.py
# │   │           │       │   │   ├── __init__.py
# │   │           │       │   │   ├── __pycache__
# │   │           │       │   │   │   ├── _base.cpython-38.pyc
# │   │           │       │   │   │   ├── __init__.cpython-38.pyc
# │   │           │       │   │   │   └── py.cpython-38.pyc
# │   │           │       │   │   └── py.py
# │   │           │       │   └── _utils.py
# │   │           │       ├── html5lib-1.1.dist-info
# │   │           │       │   ├── AUTHORS.rst
# │   │           │       │   ├── INSTALLER
# │   │           │       │   ├── LICENSE
# │   │           │       │   ├── METADATA
# │   │           │       │   ├── RECORD
# │   │           │       │   ├── REQUESTED
# │   │           │       │   ├── top_level.txt
# │   │           │       │   └── WHEEL
# │   │           │       ├── __init__.py
# │   │           │       ├── parse.py
# │   │           │       ├── parse.py.SHA256SUM
# │   │           │       ├── __pycache__
# │   │           │       │   ├── __init__.cpython-38.pyc
# │   │           │       │   └── parse.cpython-38.pyc
# │   │           │       ├── README.rst
# │   │           │       ├── vendor_install.sh
# │   │           │       └── vendor.txt
# │   │           ├── bleach-5.0.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── blis
# │   │           │   ├── about.py
# │   │           │   ├── benchmark.py
# │   │           │   ├── cy.cpython-38-x86_64-linux-gnu.so
# │   │           │   ├── cy.pxd
# │   │           │   ├── cy.pyx
# │   │           │   ├── __init__.pxd
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── about.cpython-38.pyc
# │   │           │   │   ├── benchmark.cpython-38.pyc
# │   │           │   │   └── __init__.cpython-38.pyc
# │   │           │   ├── py.cpython-38-x86_64-linux-gnu.so
# │   │           │   ├── py.pyx
# │   │           │   └── tests
# │   │           │       ├── common.py
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── common.cpython-38.pyc
# │   │           │       │   ├── __init__.cpython-38.pyc
# │   │           │       │   ├── test_dotv.cpython-38.pyc
# │   │           │       │   └── test_gemm.cpython-38.pyc
# │   │           │       ├── test_dotv.py
# │   │           │       └── test_gemm.py
# │   │           ├── blis-0.7.8.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── bs4
# │   │           │   ├── builder
# │   │           │   │   ├── _html5lib.py
# │   │           │   │   ├── _htmlparser.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── _lxml.py
# │   │           │   │   └── __pycache__
# │   │           │   │       ├── _html5lib.cpython-38.pyc
# │   │           │   │       ├── _htmlparser.cpython-38.pyc
# │   │           │   │       ├── __init__.cpython-38.pyc
# │   │           │   │       └── _lxml.cpython-38.pyc
# │   │           │   ├── dammit.py
# │   │           │   ├── diagnose.py
# │   │           │   ├── element.py
# │   │           │   ├── formatter.py
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── dammit.cpython-38.pyc
# │   │           │   │   ├── diagnose.cpython-38.pyc
# │   │           │   │   ├── element.cpython-38.pyc
# │   │           │   │   ├── formatter.cpython-38.pyc
# │   │           │   │   └── __init__.cpython-38.pyc
# │   │           │   └── tests
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── __init__.cpython-38.pyc
# │   │           │       │   ├── test_builder.cpython-38.pyc
# │   │           │       │   ├── test_builder_registry.cpython-38.pyc
# │   │           │       │   ├── test_dammit.cpython-38.pyc
# │   │           │       │   ├── test_docs.cpython-38.pyc
# │   │           │       │   ├── test_element.cpython-38.pyc
# │   │           │       │   ├── test_formatter.cpython-38.pyc
# │   │           │       │   ├── test_html5lib.cpython-38.pyc
# │   │           │       │   ├── test_htmlparser.cpython-38.pyc
# │   │           │       │   ├── test_lxml.cpython-38.pyc
# │   │           │       │   ├── test_navigablestring.cpython-38.pyc
# │   │           │       │   ├── test_pageelement.cpython-38.pyc
# │   │           │       │   ├── test_soup.cpython-38.pyc
# │   │           │       │   ├── test_tag.cpython-38.pyc
# │   │           │       │   └── test_tree.cpython-38.pyc
# │   │           │       ├── test_builder.py
# │   │           │       ├── test_builder_registry.py
# │   │           │       ├── test_dammit.py
# │   │           │       ├── test_docs.py
# │   │           │       ├── test_element.py
# │   │           │       ├── test_formatter.py
# │   │           │       ├── test_html5lib.py
# │   │           │       ├── test_htmlparser.py
# │   │           │       ├── test_lxml.py
# │   │           │       ├── test_navigablestring.py
# │   │           │       ├── test_pageelement.py
# │   │           │       ├── test_soup.py
# │   │           │       ├── test_tag.py
# │   │           │       └── test_tree.py
# │   │           ├── catalogue
# │   │           │   ├── _importlib_metadata
# │   │           │   │   ├── _compat.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   └── __pycache__
# │   │           │   │       ├── _compat.cpython-38.pyc
# │   │           │   │       └── __init__.cpython-38.pyc
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   └── __init__.cpython-38.pyc
# │   │           │   └── tests
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── __init__.cpython-38.pyc
# │   │           │       │   └── test_catalogue.cpython-38.pyc
# │   │           │       └── test_catalogue.py
# │   │           ├── catalogue-2.0.7.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   ├── WHEEL
# │   │           │   └── zip-safe
# │   │           ├── certifi
# │   │           │   ├── cacert.pem
# │   │           │   ├── core.py
# │   │           │   ├── __init__.py
# │   │           │   ├── __main__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── core.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   └── __main__.cpython-38.pyc
# │   │           │   └── py.typed
# │   │           ├── certifi-2022.6.15.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── cffi
# │   │           │   ├── api.py
# │   │           │   ├── backend_ctypes.py
# │   │           │   ├── _cffi_errors.h
# │   │           │   ├── _cffi_include.h
# │   │           │   ├── cffi_opcode.py
# │   │           │   ├── commontypes.py
# │   │           │   ├── cparser.py
# │   │           │   ├── _embedding.h
# │   │           │   ├── error.py
# │   │           │   ├── ffiplatform.py
# │   │           │   ├── __init__.py
# │   │           │   ├── lock.py
# │   │           │   ├── model.py
# │   │           │   ├── parse_c_type.h
# │   │           │   ├── pkgconfig.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── api.cpython-38.pyc
# │   │           │   │   ├── backend_ctypes.cpython-38.pyc
# │   │           │   │   ├── cffi_opcode.cpython-38.pyc
# │   │           │   │   ├── commontypes.cpython-38.pyc
# │   │           │   │   ├── cparser.cpython-38.pyc
# │   │           │   │   ├── error.cpython-38.pyc
# │   │           │   │   ├── ffiplatform.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── lock.cpython-38.pyc
# │   │           │   │   ├── model.cpython-38.pyc
# │   │           │   │   ├── pkgconfig.cpython-38.pyc
# │   │           │   │   ├── recompiler.cpython-38.pyc
# │   │           │   │   ├── setuptools_ext.cpython-38.pyc
# │   │           │   │   ├── vengine_cpy.cpython-38.pyc
# │   │           │   │   ├── vengine_gen.cpython-38.pyc
# │   │           │   │   └── verifier.cpython-38.pyc
# │   │           │   ├── recompiler.py
# │   │           │   ├── setuptools_ext.py
# │   │           │   ├── vengine_cpy.py
# │   │           │   ├── vengine_gen.py
# │   │           │   └── verifier.py
# │   │           ├── cffi-1.15.0.dist-info
# │   │           │   ├── entry_points.txt
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── _cffi_backend.cpython-38-x86_64-linux-gnu.so
# │   │           ├── cffi.libs
# │   │           │   └── libffi-9c61262e.so.8.1.0
# │   │           ├── charset_normalizer
# │   │           │   ├── api.py
# │   │           │   ├── assets
# │   │           │   │   ├── __init__.py
# │   │           │   │   └── __pycache__
# │   │           │   │       └── __init__.cpython-38.pyc
# │   │           │   ├── cd.py
# │   │           │   ├── cli
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── normalizer.py
# │   │           │   │   └── __pycache__
# │   │           │   │       ├── __init__.cpython-38.pyc
# │   │           │   │       └── normalizer.cpython-38.pyc
# │   │           │   ├── constant.py
# │   │           │   ├── __init__.py
# │   │           │   ├── legacy.py
# │   │           │   ├── md.py
# │   │           │   ├── models.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── api.cpython-38.pyc
# │   │           │   │   ├── cd.cpython-38.pyc
# │   │           │   │   ├── constant.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── legacy.cpython-38.pyc
# │   │           │   │   ├── md.cpython-38.pyc
# │   │           │   │   ├── models.cpython-38.pyc
# │   │           │   │   ├── utils.cpython-38.pyc
# │   │           │   │   └── version.cpython-38.pyc
# │   │           │   ├── py.typed
# │   │           │   ├── utils.py
# │   │           │   └── version.py
# │   │           ├── charset_normalizer-2.0.12.dist-info
# │   │           │   ├── entry_points.txt
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── click
# │   │           │   ├── _compat.py
# │   │           │   ├── core.py
# │   │           │   ├── decorators.py
# │   │           │   ├── exceptions.py
# │   │           │   ├── formatting.py
# │   │           │   ├── globals.py
# │   │           │   ├── __init__.py
# │   │           │   ├── parser.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── _compat.cpython-38.pyc
# │   │           │   │   ├── core.cpython-38.pyc
# │   │           │   │   ├── decorators.cpython-38.pyc
# │   │           │   │   ├── exceptions.cpython-38.pyc
# │   │           │   │   ├── formatting.cpython-38.pyc
# │   │           │   │   ├── globals.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── parser.cpython-38.pyc
# │   │           │   │   ├── shell_completion.cpython-38.pyc
# │   │           │   │   ├── termui.cpython-38.pyc
# │   │           │   │   ├── _termui_impl.cpython-38.pyc
# │   │           │   │   ├── testing.cpython-38.pyc
# │   │           │   │   ├── _textwrap.cpython-38.pyc
# │   │           │   │   ├── types.cpython-38.pyc
# │   │           │   │   ├── utils.cpython-38.pyc
# │   │           │   │   └── _winconsole.cpython-38.pyc
# │   │           │   ├── py.typed
# │   │           │   ├── shell_completion.py
# │   │           │   ├── _termui_impl.py
# │   │           │   ├── termui.py
# │   │           │   ├── testing.py
# │   │           │   ├── _textwrap.py
# │   │           │   ├── types.py
# │   │           │   ├── utils.py
# │   │           │   └── _winconsole.py
# │   │           ├── click-8.1.3.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE.rst
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── cycler-0.11.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── cycler.py
# │   │           ├── cymem
# │   │           │   ├── about.py
# │   │           │   ├── cymem.cpython-38-x86_64-linux-gnu.so
# │   │           │   ├── cymem.pxd
# │   │           │   ├── cymem.pyx
# │   │           │   ├── __init__.pxd
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── about.cpython-38.pyc
# │   │           │   │   └── __init__.cpython-38.pyc
# │   │           │   └── tests
# │   │           │       ├── __pycache__
# │   │           │       │   └── test_import.cpython-38.pyc
# │   │           │       └── test_import.py
# │   │           ├── cymem-2.0.6.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── top_level.txt
# │   │           │   └── WHEEL
# │   │           ├── dateutil
# │   │           │   ├── _common.py
# │   │           │   ├── easter.py
# │   │           │   ├── __init__.py
# │   │           │   ├── parser
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── isoparser.py
# │   │           │   │   ├── _parser.py
# │   │           │   │   └── __pycache__
# │   │           │   │       ├── __init__.cpython-38.pyc
# │   │           │   │       ├── isoparser.cpython-38.pyc
# │   │           │   │       └── _parser.cpython-38.pyc
# │   │           │   ├── __pycache__
# │   │           │   │   ├── _common.cpython-38.pyc
# │   │           │   │   ├── easter.cpython-38.pyc
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── relativedelta.cpython-38.pyc
# │   │           │   │   ├── rrule.cpython-38.pyc
# │   │           │   │   ├── tzwin.cpython-38.pyc
# │   │           │   │   ├── utils.cpython-38.pyc
# │   │           │   │   └── _version.cpython-38.pyc
# │   │           │   ├── relativedelta.py
# │   │           │   ├── rrule.py
# │   │           │   ├── tz
# │   │           │   │   ├── _common.py
# │   │           │   │   ├── _factories.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── _common.cpython-38.pyc
# │   │           │   │   │   ├── _factories.cpython-38.pyc
# │   │           │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   ├── tz.cpython-38.pyc
# │   │           │   │   │   └── win.cpython-38.pyc
# │   │           │   │   ├── tz.py
# │   │           │   │   └── win.py
# │   │           │   ├── tzwin.py
# │   │           │   ├── utils.py
# │   │           │   ├── _version.py
# │   │           │   └── zoneinfo
# │   │           │       ├── dateutil-zoneinfo.tar.gz
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── __init__.cpython-38.pyc
# │   │           │       │   └── rebuild.cpython-38.pyc
# │   │           │       └── rebuild.py
# │   │           ├── debugpy
# │   │           │   ├── adapter
# │   │           │   │   ├── clients.py
# │   │           │   │   ├── components.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── launchers.py
# │   │           │   │   ├── __main__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── clients.cpython-38.pyc
# │   │           │   │   │   ├── components.cpython-38.pyc
# │   │           │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   ├── launchers.cpython-38.pyc
# │   │           │   │   │   ├── __main__.cpython-38.pyc
# │   │           │   │   │   ├── servers.cpython-38.pyc
# │   │           │   │   │   └── sessions.cpython-38.pyc
# │   │           │   │   ├── servers.py
# │   │           │   │   └── sessions.py
# │   │           │   ├── common
# │   │           │   │   ├── compat.py
# │   │           │   │   ├── fmt.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── json.py
# │   │           │   │   ├── log.py
# │   │           │   │   ├── messaging.py
# │   │           │   │   ├── modules.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── compat.cpython-38.pyc
# │   │           │   │   │   ├── fmt.cpython-38.pyc
# │   │           │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   ├── json.cpython-38.pyc
# │   │           │   │   │   ├── log.cpython-38.pyc
# │   │           │   │   │   ├── messaging.cpython-38.pyc
# │   │           │   │   │   ├── modules.cpython-38.pyc
# │   │           │   │   │   ├── singleton.cpython-38.pyc
# │   │           │   │   │   ├── sockets.cpython-38.pyc
# │   │           │   │   │   ├── stacks.cpython-38.pyc
# │   │           │   │   │   ├── timestamp.cpython-38.pyc
# │   │           │   │   │   └── util.cpython-38.pyc
# │   │           │   │   ├── singleton.py
# │   │           │   │   ├── sockets.py
# │   │           │   │   ├── stacks.py
# │   │           │   │   ├── timestamp.py
# │   │           │   │   └── util.py
# │   │           │   ├── __init__.py
# │   │           │   ├── launcher
# │   │           │   │   ├── debuggee.py
# │   │           │   │   ├── handlers.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __main__.py
# │   │           │   │   ├── output.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── debuggee.cpython-38.pyc
# │   │           │   │   │   ├── handlers.cpython-38.pyc
# │   │           │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   ├── __main__.cpython-38.pyc
# │   │           │   │   │   ├── output.cpython-38.pyc
# │   │           │   │   │   └── winapi.cpython-38.pyc
# │   │           │   │   └── winapi.py
# │   │           │   ├── __main__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   ├── __main__.cpython-38.pyc
# │   │           │   │   └── _version.cpython-38.pyc
# │   │           │   ├── server
# │   │           │   │   ├── api.py
# │   │           │   │   ├── attach_pid_injected.py
# │   │           │   │   ├── cli.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   └── __pycache__
# │   │           │   │       ├── api.cpython-38.pyc
# │   │           │   │       ├── attach_pid_injected.cpython-38.pyc
# │   │           │   │       ├── cli.cpython-38.pyc
# │   │           │   │       └── __init__.cpython-38.pyc
# │   │           │   ├── ThirdPartyNotices.txt
# │   │           │   ├── _vendored
# │   │           │   │   ├── force_pydevd.py
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── force_pydevd.cpython-38.pyc
# │   │           │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   ├── _pydevd_packaging.cpython-38.pyc
# │   │           │   │   │   └── _util.cpython-38.pyc
# │   │           │   │   ├── pydevd
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── pydev_app_engine_debug_startup.cpython-38.pyc
# │   │           │   │   │   │   ├── pydevconsole.cpython-38.pyc
# │   │           │   │   │   │   ├── pydev_coverage.cpython-38.pyc
# │   │           │   │   │   │   ├── pydevd.cpython-38.pyc
# │   │           │   │   │   │   ├── pydevd_file_utils.cpython-38.pyc
# │   │           │   │   │   │   ├── pydevd_tracing.cpython-38.pyc
# │   │           │   │   │   │   ├── pydev_pysrc.cpython-38.pyc
# │   │           │   │   │   │   ├── pydev_run_in_console.cpython-38.pyc
# │   │           │   │   │   │   └── setup_pydevd_cython.cpython-38.pyc
# │   │           │   │   │   ├── pydev_app_engine_debug_startup.py
# │   │           │   │   │   ├── _pydev_bundle
# │   │           │   │   │   │   ├── fsnotify
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   └── __pycache__
# │   │           │   │   │   │   │       └── __init__.cpython-38.pyc
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_calltip_util.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_completer.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_console_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_execfile.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_filesystem_encoding.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_getopt.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_import_hook.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_imports.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_imports_tipper.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_ipython_console_011.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_ipython_console.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_is_thread_alive.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_jy_imports_tipper.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_localhost.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_log.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_log.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_monkey.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_monkey_qt.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_override.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_saved_modules.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_sys_patch.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _pydev_tipper_common.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydev_umd.cpython-38.pyc
# │   │           │   │   │   │   │   └── pydev_versioncheck.cpython-38.pyc
# │   │           │   │   │   │   ├── _pydev_calltip_util.py
# │   │           │   │   │   │   ├── _pydev_completer.py
# │   │           │   │   │   │   ├── pydev_console_utils.py
# │   │           │   │   │   │   ├── _pydev_execfile.py
# │   │           │   │   │   │   ├── _pydev_filesystem_encoding.py
# │   │           │   │   │   │   ├── _pydev_getopt.py
# │   │           │   │   │   │   ├── pydev_import_hook.py
# │   │           │   │   │   │   ├── pydev_imports.py
# │   │           │   │   │   │   ├── _pydev_imports_tipper.py
# │   │           │   │   │   │   ├── pydev_ipython_console_011.py
# │   │           │   │   │   │   ├── pydev_ipython_console.py
# │   │           │   │   │   │   ├── pydev_is_thread_alive.py
# │   │           │   │   │   │   ├── _pydev_jy_imports_tipper.py
# │   │           │   │   │   │   ├── pydev_localhost.py
# │   │           │   │   │   │   ├── _pydev_log.py
# │   │           │   │   │   │   ├── pydev_log.py
# │   │           │   │   │   │   ├── pydev_monkey.py
# │   │           │   │   │   │   ├── pydev_monkey_qt.py
# │   │           │   │   │   │   ├── pydev_override.py
# │   │           │   │   │   │   ├── _pydev_saved_modules.py
# │   │           │   │   │   │   ├── _pydev_sys_patch.py
# │   │           │   │   │   │   ├── _pydev_tipper_common.py
# │   │           │   │   │   │   ├── pydev_umd.py
# │   │           │   │   │   │   └── pydev_versioncheck.py
# │   │           │   │   │   ├── pydevconsole.py
# │   │           │   │   │   ├── pydev_coverage.py
# │   │           │   │   │   ├── pydevd_attach_to_process
# │   │           │   │   │   │   ├── add_code_to_python_process.py
# │   │           │   │   │   │   ├── _always_live_program.py
# │   │           │   │   │   │   ├── attach_linux_amd64.so
# │   │           │   │   │   │   ├── attach_pydevd.py
# │   │           │   │   │   │   ├── attach_script.py
# │   │           │   │   │   │   ├── _check.py
# │   │           │   │   │   │   ├── common
# │   │           │   │   │   │   │   ├── py_custom_pyeval_settrace_310.hpp
# │   │           │   │   │   │   │   ├── py_custom_pyeval_settrace_common.hpp
# │   │           │   │   │   │   │   ├── py_custom_pyeval_settrace.hpp
# │   │           │   │   │   │   │   ├── py_settrace.hpp
# │   │           │   │   │   │   │   ├── python.h
# │   │           │   │   │   │   │   ├── py_utils.hpp
# │   │           │   │   │   │   │   ├── py_version.hpp
# │   │           │   │   │   │   │   └── ref_utils.hpp
# │   │           │   │   │   │   ├── linux_and_mac
# │   │           │   │   │   │   │   ├── attach.cpp
# │   │           │   │   │   │   │   ├── compile_linux.sh
# │   │           │   │   │   │   │   ├── compile_mac.sh
# │   │           │   │   │   │   │   ├── compile_manylinux.cmd
# │   │           │   │   │   │   │   ├── lldb_prepare.py
# │   │           │   │   │   │   │   └── __pycache__
# │   │           │   │   │   │   │       └── lldb_prepare.cpython-38.pyc
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── add_code_to_python_process.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _always_live_program.cpython-38.pyc
# │   │           │   │   │   │   │   ├── attach_pydevd.cpython-38.pyc
# │   │           │   │   │   │   │   ├── attach_script.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _check.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _test_attach_to_process.cpython-38.pyc
# │   │           │   │   │   │   │   └── _test_attach_to_process_linux.cpython-38.pyc
# │   │           │   │   │   │   ├── README.txt
# │   │           │   │   │   │   ├── _test_attach_to_process_linux.py
# │   │           │   │   │   │   ├── _test_attach_to_process.py
# │   │           │   │   │   │   ├── winappdbg
# │   │           │   │   │   │   │   ├── breakpoint.py
# │   │           │   │   │   │   │   ├── compat.py
# │   │           │   │   │   │   │   ├── crash.py
# │   │           │   │   │   │   │   ├── debug.py
# │   │           │   │   │   │   │   ├── disasm.py
# │   │           │   │   │   │   │   ├── event.py
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   ├── interactive.py
# │   │           │   │   │   │   │   ├── module.py
# │   │           │   │   │   │   │   ├── process.py
# │   │           │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   ├── breakpoint.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── compat.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── crash.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── debug.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── disasm.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── event.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── interactive.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── module.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── process.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── registry.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── search.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── sql.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── system.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── textio.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── thread.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── util.cpython-38.pyc
# │   │           │   │   │   │   │   │   └── window.cpython-38.pyc
# │   │           │   │   │   │   │   ├── registry.py
# │   │           │   │   │   │   │   ├── search.py
# │   │           │   │   │   │   │   ├── sql.py
# │   │           │   │   │   │   │   ├── system.py
# │   │           │   │   │   │   │   ├── textio.py
# │   │           │   │   │   │   │   ├── thread.py
# │   │           │   │   │   │   │   ├── util.py
# │   │           │   │   │   │   │   ├── win32
# │   │           │   │   │   │   │   │   ├── advapi32.py
# │   │           │   │   │   │   │   │   ├── context_amd64.py
# │   │           │   │   │   │   │   │   ├── context_i386.py
# │   │           │   │   │   │   │   │   ├── dbghelp.py
# │   │           │   │   │   │   │   │   ├── defines.py
# │   │           │   │   │   │   │   │   ├── gdi32.py
# │   │           │   │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   │   ├── kernel32.py
# │   │           │   │   │   │   │   │   ├── ntdll.py
# │   │           │   │   │   │   │   │   ├── peb_teb.py
# │   │           │   │   │   │   │   │   ├── psapi.py
# │   │           │   │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   │   ├── advapi32.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── context_amd64.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── context_i386.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── dbghelp.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── defines.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── gdi32.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── kernel32.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── ntdll.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── peb_teb.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── psapi.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── shell32.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── shlwapi.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── user32.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   ├── version.cpython-38.pyc
# │   │           │   │   │   │   │   │   │   └── wtsapi32.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── shell32.py
# │   │           │   │   │   │   │   │   ├── shlwapi.py
# │   │           │   │   │   │   │   │   ├── user32.py
# │   │           │   │   │   │   │   │   ├── version.py
# │   │           │   │   │   │   │   │   └── wtsapi32.py
# │   │           │   │   │   │   │   └── window.py
# │   │           │   │   │   │   └── windows
# │   │           │   │   │   │       ├── attach.cpp
# │   │           │   │   │   │       ├── attach.h
# │   │           │   │   │   │       ├── compile_windows.bat
# │   │           │   │   │   │       ├── inject_dll.cpp
# │   │           │   │   │   │       ├── py_win_helpers.hpp
# │   │           │   │   │   │       ├── run_code_in_memory.hpp
# │   │           │   │   │   │       ├── run_code_on_dllmain.cpp
# │   │           │   │   │   │       ├── stdafx.cpp
# │   │           │   │   │   │       ├── stdafx.h
# │   │           │   │   │   │       └── targetver.h
# │   │           │   │   │   ├── _pydevd_bundle
# │   │           │   │   │   │   ├── _debug_adapter
# │   │           │   │   │   │   │   ├── debugProtocolCustom.json
# │   │           │   │   │   │   │   ├── debugProtocol.json
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   ├── __main__pydevd_gen_debug_adapter_protocol.py
# │   │           │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── __main__pydevd_gen_debug_adapter_protocol.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── pydevd_base_schema.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── pydevd_schema.cpython-38.pyc
# │   │           │   │   │   │   │   │   └── pydevd_schema_log.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_base_schema.py
# │   │           │   │   │   │   │   ├── pydevd_schema_log.py
# │   │           │   │   │   │   │   └── pydevd_schema.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevconsole_code_for_ironpython.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_additional_thread_info.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_additional_thread_info_regular.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_api.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_breakpoints.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_bytecode_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_code_to_source.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_collect_bytecode_info.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_command_line_handling.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_comm_constants.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_comm.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_console.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_constants.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_custom_frames.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_cython_wrapper.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_daemon_thread.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_defaults.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_dont_trace.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_dont_trace_files.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_exec2.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_extension_api.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_extension_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_filtering.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_frame.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_frame_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_gevent_integration.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_import_class.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_io.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_json_debug_options.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_net_command.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_net_command_factory_json.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_net_command_factory_xml.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_plugin_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_process_net_command.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_process_net_command_json.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_referrers.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_reload.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_resolver.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_safe_repr.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_save_locals.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_signature.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_source_mapping.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_stackless.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_suspended_frames.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_thread_lifecycle.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_timeout.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_trace_api.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_trace_dispatch.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_trace_dispatch_regular.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_traceproperty.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_utils.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_vars.cpython-38.pyc
# │   │           │   │   │   │   │   ├── pydevd_vm_type.cpython-38.pyc
# │   │           │   │   │   │   │   └── pydevd_xml.cpython-38.pyc
# │   │           │   │   │   │   ├── pydevconsole_code_for_ironpython.py
# │   │           │   │   │   │   ├── pydevd_additional_thread_info.py
# │   │           │   │   │   │   ├── pydevd_additional_thread_info_regular.py
# ...
# │   │           │   │   │   │   ├── _hovertemplatesrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _hovertext.cpython-38.pyc
# │   │           │   │   │   │   ├── _hovertextsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _ids.cpython-38.pyc
# │   │           │   │   │   │   ├── _idssrc.cpython-38.pyc
# │   │           │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   ├── _insidetextfont.cpython-38.pyc
# │   │           │   │   │   │   ├── _insidetextorientation.cpython-38.pyc
# │   │           │   │   │   │   ├── _label0.cpython-38.pyc
# │   │           │   │   │   │   ├── _labels.cpython-38.pyc
# │   │           │   │   │   │   ├── _labelssrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendgroup.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendgrouptitle.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendrank.cpython-38.pyc
# │   │           │   │   │   │   ├── _marker.cpython-38.pyc
# │   │           │   │   │   │   ├── _meta.cpython-38.pyc
# │   │           │   │   │   │   ├── _metasrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _name.cpython-38.pyc
# │   │           │   │   │   │   ├── _opacity.cpython-38.pyc
# │   │           │   │   │   │   ├── _outsidetextfont.cpython-38.pyc
# │   │           │   │   │   │   ├── _pull.cpython-38.pyc
# │   │           │   │   │   │   ├── _pullsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _rotation.cpython-38.pyc
# │   │           │   │   │   │   ├── _scalegroup.cpython-38.pyc
# │   │           │   │   │   │   ├── _showlegend.cpython-38.pyc
# │   │           │   │   │   │   ├── _sort.cpython-38.pyc
# │   │           │   │   │   │   ├── _stream.cpython-38.pyc
# │   │           │   │   │   │   ├── _text.cpython-38.pyc
# │   │           │   │   │   │   ├── _textfont.cpython-38.pyc
# │   │           │   │   │   │   ├── _textinfo.cpython-38.pyc
# │   │           │   │   │   │   ├── _textposition.cpython-38.pyc
# │   │           │   │   │   │   ├── _textpositionsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _textsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _texttemplate.cpython-38.pyc
# │   │           │   │   │   │   ├── _texttemplatesrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _title.cpython-38.pyc
# │   │           │   │   │   │   ├── _uid.cpython-38.pyc
# │   │           │   │   │   │   ├── _uirevision.cpython-38.pyc
# │   │           │   │   │   │   ├── _values.cpython-38.pyc
# │   │           │   │   │   │   ├── _valuessrc.cpython-38.pyc
# │   │           │   │   │   │   └── _visible.cpython-38.pyc
# │   │           │   │   │   ├── _rotation.py
# │   │           │   │   │   ├── _scalegroup.py
# │   │           │   │   │   ├── _showlegend.py
# │   │           │   │   │   ├── _sort.py
# │   │           │   │   │   ├── stream
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── _maxpoints.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _maxpoints.cpython-38.pyc
# │   │           │   │   │   │   │   └── _token.cpython-38.pyc
# │   │           │   │   │   │   └── _token.py
# │   │           │   │   │   ├── _stream.py
# │   │           │   │   │   ├── textfont
# │   │           │   │   │   │   ├── _color.py
# │   │           │   │   │   │   ├── _colorsrc.py
# │   │           │   │   │   │   ├── _family.py
# │   │           │   │   │   │   ├── _familysrc.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _colorsrc.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _family.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _familysrc.cpython-38.pyc
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _size.cpython-38.pyc
# │   │           │   │   │   │   │   └── _sizesrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _size.py
# │   │           │   │   │   │   └── _sizesrc.py
# │   │           │   │   │   ├── _textfont.py
# │   │           │   │   │   ├── _textinfo.py
# │   │           │   │   │   ├── _textposition.py
# │   │           │   │   │   ├── _textpositionsrc.py
# │   │           │   │   │   ├── _text.py
# │   │           │   │   │   ├── _textsrc.py
# │   │           │   │   │   ├── _texttemplate.py
# │   │           │   │   │   ├── _texttemplatesrc.py
# │   │           │   │   │   ├── title
# │   │           │   │   │   │   ├── font
# │   │           │   │   │   │   │   ├── _color.py
# │   │           │   │   │   │   │   ├── _colorsrc.py
# │   │           │   │   │   │   │   ├── _family.py
# │   │           │   │   │   │   │   ├── _familysrc.py
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _colorsrc.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _family.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _familysrc.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _size.cpython-38.pyc
# │   │           │   │   │   │   │   │   └── _sizesrc.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _size.py
# │   │           │   │   │   │   │   └── _sizesrc.py
# │   │           │   │   │   │   ├── _font.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── _position.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── _font.cpython-38.pyc
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _position.cpython-38.pyc
# │   │           │   │   │   │   │   └── _text.cpython-38.pyc
# │   │           │   │   │   │   └── _text.py
# │   │           │   │   │   ├── _title.py
# │   │           │   │   │   ├── _uid.py
# │   │           │   │   │   ├── _uirevision.py
# │   │           │   │   │   ├── _values.py
# │   │           │   │   │   ├── _valuessrc.py
# │   │           │   │   │   └── _visible.py
# │   │           │   │   ├── _pie.py
# │   │           │   │   ├── pointcloud
# │   │           │   │   │   ├── _customdata.py
# │   │           │   │   │   ├── _customdatasrc.py
# │   │           │   │   │   ├── _hoverinfo.py
# │   │           │   │   │   ├── _hoverinfosrc.py
# │   │           │   │   │   ├── hoverlabel
# │   │           │   │   │   │   ├── _align.py
# │   │           │   │   │   │   ├── _alignsrc.py
# │   │           │   │   │   │   ├── _bgcolor.py
# │   │           │   │   │   │   ├── _bgcolorsrc.py
# │   │           │   │   │   │   ├── _bordercolor.py
# │   │           │   │   │   │   ├── _bordercolorsrc.py
# │   │           │   │   │   │   ├── font
# │   │           │   │   │   │   │   ├── _color.py
# │   │           │   │   │   │   │   ├── _colorsrc.py
# │   │           │   │   │   │   │   ├── _family.py
# │   │           │   │   │   │   │   ├── _familysrc.py
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _colorsrc.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _family.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _familysrc.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _size.cpython-38.pyc
# │   │           │   │   │   │   │   │   └── _sizesrc.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _size.py
# │   │           │   │   │   │   │   └── _sizesrc.py
# │   │           │   │   │   │   ├── _font.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── _namelength.py
# │   │           │   │   │   │   ├── _namelengthsrc.py
# │   │           │   │   │   │   └── __pycache__
# │   │           │   │   │   │       ├── _align.cpython-38.pyc
# │   │           │   │   │   │       ├── _alignsrc.cpython-38.pyc
# │   │           │   │   │   │       ├── _bgcolor.cpython-38.pyc
# │   │           │   │   │   │       ├── _bgcolorsrc.cpython-38.pyc
# │   │           │   │   │   │       ├── _bordercolor.cpython-38.pyc
# │   │           │   │   │   │       ├── _bordercolorsrc.cpython-38.pyc
# │   │           │   │   │   │       ├── _font.cpython-38.pyc
# │   │           │   │   │   │       ├── __init__.cpython-38.pyc
# │   │           │   │   │   │       ├── _namelength.cpython-38.pyc
# │   │           │   │   │   │       └── _namelengthsrc.cpython-38.pyc
# │   │           │   │   │   ├── _hoverlabel.py
# │   │           │   │   │   ├── _ids.py
# │   │           │   │   │   ├── _idssrc.py
# │   │           │   │   │   ├── _indices.py
# │   │           │   │   │   ├── _indicessrc.py
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── _legendgroup.py
# │   │           │   │   │   ├── legendgrouptitle
# │   │           │   │   │   │   ├── font
# │   │           │   │   │   │   │   ├── _color.py
# │   │           │   │   │   │   │   ├── _family.py
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   │   ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── _family.cpython-38.pyc
# │   │           │   │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   │   └── _size.cpython-38.pyc
# │   │           │   │   │   │   │   └── _size.py
# │   │           │   │   │   │   ├── _font.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── _font.cpython-38.pyc
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   └── _text.cpython-38.pyc
# │   │           │   │   │   │   └── _text.py
# │   │           │   │   │   ├── _legendgrouptitle.py
# │   │           │   │   │   ├── _legendrank.py
# │   │           │   │   │   ├── marker
# │   │           │   │   │   │   ├── _blend.py
# │   │           │   │   │   │   ├── border
# │   │           │   │   │   │   │   ├── _arearatio.py
# │   │           │   │   │   │   │   ├── _color.py
# │   │           │   │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   │   └── __pycache__
# │   │           │   │   │   │   │       ├── _arearatio.cpython-38.pyc
# │   │           │   │   │   │   │       ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │       └── __init__.cpython-38.pyc
# │   │           │   │   │   │   ├── _border.py
# │   │           │   │   │   │   ├── _color.py
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── _opacity.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── _blend.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _border.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _color.cpython-38.pyc
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _opacity.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _sizemax.cpython-38.pyc
# │   │           │   │   │   │   │   └── _sizemin.cpython-38.pyc
# │   │           │   │   │   │   ├── _sizemax.py
# │   │           │   │   │   │   └── _sizemin.py
# │   │           │   │   │   ├── _marker.py
# │   │           │   │   │   ├── _meta.py
# │   │           │   │   │   ├── _metasrc.py
# │   │           │   │   │   ├── _name.py
# │   │           │   │   │   ├── _opacity.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── _customdata.cpython-38.pyc
# │   │           │   │   │   │   ├── _customdatasrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _hoverinfo.cpython-38.pyc
# │   │           │   │   │   │   ├── _hoverinfosrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _hoverlabel.cpython-38.pyc
# │   │           │   │   │   │   ├── _ids.cpython-38.pyc
# │   │           │   │   │   │   ├── _idssrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _indices.cpython-38.pyc
# │   │           │   │   │   │   ├── _indicessrc.cpython-38.pyc
# │   │           │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendgroup.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendgrouptitle.cpython-38.pyc
# │   │           │   │   │   │   ├── _legendrank.cpython-38.pyc
# │   │           │   │   │   │   ├── _marker.cpython-38.pyc
# │   │           │   │   │   │   ├── _meta.cpython-38.pyc
# │   │           │   │   │   │   ├── _metasrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _name.cpython-38.pyc
# │   │           │   │   │   │   ├── _opacity.cpython-38.pyc
# │   │           │   │   │   │   ├── _showlegend.cpython-38.pyc
# │   │           │   │   │   │   ├── _stream.cpython-38.pyc
# │   │           │   │   │   │   ├── _text.cpython-38.pyc
# │   │           │   │   │   │   ├── _textsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _uid.cpython-38.pyc
# │   │           │   │   │   │   ├── _uirevision.cpython-38.pyc
# │   │           │   │   │   │   ├── _visible.cpython-38.pyc
# │   │           │   │   │   │   ├── _xaxis.cpython-38.pyc
# │   │           │   │   │   │   ├── _xbounds.cpython-38.pyc
# │   │           │   │   │   │   ├── _xboundssrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _x.cpython-38.pyc
# │   │           │   │   │   │   ├── _xsrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _xy.cpython-38.pyc
# │   │           │   │   │   │   ├── _xysrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _yaxis.cpython-38.pyc
# │   │           │   │   │   │   ├── _ybounds.cpython-38.pyc
# │   │           │   │   │   │   ├── _yboundssrc.cpython-38.pyc
# │   │           │   │   │   │   ├── _y.cpython-38.pyc
# │   │           │   │   │   │   └── _ysrc.cpython-38.pyc
# │   │           │   │   │   ├── _showlegend.py
# │   │           │   │   │   ├── stream
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── _maxpoints.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-38.pyc
# │   │           │   │   │   │   │   ├── _maxpoints.cpython-38.pyc
# │   │           │   │   │   │   │   └── _token.cpython-38.pyc
# │   │           │   │   │   │   └── _token.py
# │   │           │   │   │   ├── _stream.py
# │   │           │   │   │   ├── _text.py
# │   │           │   │   │   ├── _textsrc.py
# │   │           │   │   │   ├── _uid.py
# │   │           │   │   │   ├── _uirevision.py
# │   │           │   │   │   ├── _visible.py
# │   │           │   │   │   ├── _xaxis.py
# │   │           │   │   │   ├── _xbounds.py
# │   │           │   │   │   ├── _xboundssrc.py
# │   │           │   │   │   ├── _x.py
# │   │           │   │   │   ├── _xsrc.py
# │   │           │   │   │   ├── _xy.py
# │   │           │   │   │   ├── _xysrc.py
# │   │           │   │   │   ├── _yaxis.py
# │   │           │   │   │   ├── _ybounds.py
# │   │           │   │   │   ├── _yboundssrc.py
# │   │           │   │   │   ├── _y.py
# │   │           │   │   │   └── _ysrc.py
# │   │           │   │   ├── _pointcloud.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── _bar.cpython-38.pyc
# │   │           │   │   │   ├── _barpolar.cpython-38.pyc
# │   │           │   │   │   ├── _box.cpython-38.pyc
# │   │           │   │   │   ├── _candlestick.cpython-38.pyc
# │   │           │   │   │   ├── _carpet.cpython-38.pyc
# │   │           │   │   │   ├── _choropleth.cpython-38.pyc
# │   │           │   │   │   ├── _choroplethmapbox.cpython-38.pyc
# │   │           │   │   │   ├── _cone.cpython-38.pyc
# │   │           │   │   │   ├── _contourcarpet.cpython-38.pyc
# │   │           │   │   │   ├── _c
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# our file

data = "./data/source/"
os.listdir(data)
# Out:
# ['superheroes_nlp_dataset.csv', 'twit_from_disaster_train.csv']

# %%
# load dataframe

fn = data + 'twit_from_disaster_train.csv'

df = pd.read_csv(fn)

# %%
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # 2. First Tour

# %% [markdown]
# ## 2.1 Display

# %%
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.sample(10)
# Out:
#          id       keyword                 location  \
# 3032   4353    earthquake                      NaN
# 3525   5039    eyewitness  Bakersfield, California
# 1584   2286  cliff%20fall                      NaN
# 7542  10783      wreckage             Xi'an, China
# 5379   7677         panic                518 åá NY
# 1460   2108      casualty                      NaN
# 1462   2110   catastrophe  Wellington, New Zealand
# 5815   8298        rubble                      NaN
# 6292   8989         storm                      NaN
# 7355  10529      wildfire                      NaN
#
#                                                    text  target
# 3032  2.0 #Earthquake in Sicily Italy #iPhone users ...       1
# 3525  Wake Up Kern County Eyewitness News Mornings a...       1
# 1584  @SZMNextDoor I got this cute lil cliff you can...       0
# 7542  Wreckage 'conclusively confirmed' as from miss...       1
# 5379  Savs contact fell out but she was convinced it...       0
# 1460  .@stavernise: France agreed to repay Russia fo...       0
# 1462  @APPLEOFFIClAL Migrating from iPhoto to Photo ...       0
# 5815  My parents are so impulsive sometimes. I remem...       0
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
# 7355  Media Release - Firefighters Ask Hikers to Sig...       1

# %%
df.tail(5)
# Out:
#          id keyword location  \
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1

# %% [markdown]
# ## 2.2 Structure

# %%
df.shape
# Out:
# (7613, 5)

# %%
df.dtypes
# Out:
# id           int64
# keyword     object
# location    object
# text        object
# target       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
df.dtypes.value_counts()
# Out:
# object    3
# int64     2
# dtype: int64

# %%
tmp = df.nunique()
tmp
# Out:
# id          7613
# keyword      221
# location    3341
# text        7503
# target         2
# dtype: int64

# %%
tmp[tmp <10]
# Out:
# target    2
# dtype: int64

# %%
tmp[tmp>1000]
# Out:
# id          7613
# location    3341
# text        7503
# dtype: int64

# %% [markdown]
# ## 2.3 NaN and duplicated

# %%
df.isna().mean().sort_values()
# Out:
# id          0.000000
# text        0.000000
# target      0.000000
# keyword     0.008013
# location    0.332720
# dtype: float64

# %%
tmp = df.isna().mean()

fig, ax = plt.subplots(1,1, figsize=(20, 6))
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns : 
    n = df.duplicated(subset=col).sum()
    print(f"col : {col} -> duplicated : {n}")
# Out:
# col : id -> duplicated : 0
# col : keyword -> duplicated : 7391
# col : location -> duplicated : 4271
# col : text -> duplicated : 110
# col : target -> duplicated : 7611

# %%
idx = df.duplicated(subset="text",keep="first")
df.loc[idx, : ].sort_values("text")
# Out:
#         id         keyword                    location  \
# 4299  6105        hellfire  ?????? ??? ?????? ????????
# 4312  6123        hellfire          ?????? ???? ??????
# 6366  9098  suicide%20bomb                     Nigeria
# 6373  9107  suicide%20bomb                     Nigeria
# 6392  9135  suicide%20bomb                     Nigeria
# ...    ...             ...                         ...
# 3461  4952        exploded                         NaN
# 6103  8714         sinking                         NaN
# 6094  8702         sinking                         NaN
# 6123  8739         sinking                          MA
# 5641  8044        refugees                         NaN
#
#                                                    text  target
# 4299  #Allah describes piling up #wealth thinking it...       0
# 4312  #Allah describes piling up #wealth thinking it...       1
# 6366  #Bestnaijamade: 16yr old PKK suicide bomber wh...       1
# 6373  #Bestnaijamade: 16yr old PKK suicide bomber wh...       1
# 6392  #Bestnaijamade: 16yr old PKK suicide bomber wh...       1
# ...                                                 ...     ...
# 3461  that exploded &amp; brought about the\nbeginni...       0
# 6103  that horrible sinking feeling when youÛªve be...       0
# 6094  that horrible sinking feeling when youÛªve be...       0
# 6123  that horrible sinking feeling when youÛªve be...       1
# 5641  wowo--=== 12000 Nigerian refugees repatriated ...       0
#
# [110 rows x 5 columns]

# %% [markdown]
# ## 2.4 Data inspection

# %%
df.describe(include=np.number)
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
df.describe(include=object)
# Out:
#            keyword location                                               text
# count         7552     5080                                               7613
# unique         221     3341                                               7503
# top     fatalities      USA  11-Year-Old Boy Charged With Manslaughter of T...
# freq            45      104                                                 10

# %% [markdown]
# # 3. Cleaning

# %% [markdown]
# ## 3.1 Select columns

# %%
tmp = df.dtypes
tmp
# Out:
# id           int64
# keyword     object
# location    object
# text        object
# target       int64
# dtype: object

# %%
tmp[tmp =="object"]
# Out:
# keyword     object
# location    object
# text        object
# dtype: object

# %%
cols = ["text", "target"]
df = df[cols]
df.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %% [markdown]
# ## 3.2 Drop NaN

# %%
df.isna().mean()
# Out:
# text      0.0
# target    0.0
# dtype: float64

# %% [markdown]
# ## 3.3 Duplicated

# %%
df.shape
# Out:
# (7613, 2)

# %%
df.drop_duplicates(subset="text", inplace=True)

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# ## 4.1 Target

# %%
df.describe()
# Out:
#             target
# count  7503.000000
# mean      0.426230
# std       0.494561
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.target.value_counts()
# Out:
# 0    4305
# 1    3198
# Name: target, dtype: int64

# %%
df.target.value_counts(normalize=True)
# Out:
# 0    0.57377
# 1    0.42623
# Name: target, dtype: float64

# %%
df.target.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='target'>

# %% [markdown]
# ## 4.2 Length

# %%
df.describe(include="object")
# Out:
#                                                      text
# count                                                7503
# unique                                               7503
# top     Our Deeds are the Reason of this #earthquake M...
# freq                                                    1

# %%
tmp = df.text.str.len()
sns.boxplot(tmp)
# Out:
# /home/alex/Desktop/ocr-donnees-textuelles/env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='text'>

# %%
sns.displot(tmp)

# %%
df["_len_txt"] = tmp

# %% [markdown]
# ## 4.3 Multivariate analysis

# %%
corr = df.corr()
corr
# Out:
#             target  _len_txt
# target    1.000000  0.180997
# _len_txt  0.180997  1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(7, 5))
ax = sns.heatmap(corr, mask=mask, vmin=-1, vmax=1, cmap="coolwarm", annot=True, fmt=".2f", square=True)

# %%
sns.pairplot(df)

# %%
df.sort_values("_len_txt").head(10)
# Out:
#             text  target  _len_txt
# 4890     Bad day       0         7
# 5115     Err:509       0         7
# 1882     Crushed       0         7
# 4971    Meltdown       0         8
# 24      LOOOOOOL       0         8
# 3670    fatality       0         8
# 30      The end!       0         8
# 28     Cooool :)       0         9
# 3667   Fatality!       0         9
# 6705  Thunder???       0        10

# %%
df.sort_values("_len_txt").tail()
# Out:
#                                                    text  target  _len_txt
# 635   @cspanwj If 90BLKs&amp;8WHTs colluded 2 take W...       1       150
# 633   @HowardU If 90BLKs&amp;8WHTs colluded 2 take W...       1       150
# 614   @CAgov If 90BLKs&amp;8WHTs colluded 2 take WHT...       1       151
# 4801  It's was about 2:30 in the morning&amp;I went ...       0       152
# 1270  when you're taking a shower and someone flushe...       0       157

# %%
sns.pairplot(df,)

# %%
sns.pairplot(df, hue="target")

# %%
df.drop(columns="_len_txt", inplace=True)
df.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %%
df.to_csv("data/cleaned/df_cleaned.csv", index=False)

# %% [markdown]
# ## 4.4. Explore corpus and documents

# %% [markdown]
# ###  4.4.1 print N random documents

# %%
df_samp = df.sample(20)
df_samp
# Out:
#                                                    text  target
# 5952                           @BizzleMahomie SCREAMING       0
# 2272  Doone Silver Architects has won permission to ...       0
# 2534  Escape The Heat (and the #ORShow) for a trail ...       0
# 6507  Ended today's staff meeting with the teacher v...       0
# 3350  Evacuation order lifted for town of Roosevelt ...       1
# 6476  @SaintRobinho86 someone has to be at the botto...       1
# 2779  Water now tops the charts for highest global r...       1
# 5241  Path of Obliteration\nBack From The Dead\nStor...       1
# 6275  What tropical storm? #guillermo by hawaiianpad...       1
# 6416  #deai #??? #??? #??? Suicide bomber kills 15 i...       1
# 556   Black Eye 9: A space battle occurred at Star M...       1
# 1146  Japan Marks 70th Anniversary of Hiroshima Atom...       1
# 2338  Remaining Sections Of Greystone Psychiatric Ho...       0
# 4756  Don't blink ?? won't see the Lightning take th...       1
# 1746  Santa Fe Springs Studebaker Rd / South St **Tr...       0
# 4107  @Haley_Whaley Hailstorm Hey There is a Secret ...       0
# 652   My hair is poverty at the moment need to get a...       0
# 5400  You made my mood go from shitty af to panickin...       0
# 3596  Deputies: Dog dispute leads to fatal shooting ...       1
# 3821  Juneau Empire - First responders turn out for ...       0

# %%
for idx, ser in df_samp.iterrows(): 

    txt_1 = f"target : {ser['target']}\n"
    print(txt_1+ser['text']+ "..." + "\n\n")
# Out:
# target : 0
# @BizzleMahomie SCREAMING...
#
#
# target : 0
# Doone Silver Architects has won permission to demolish Birmingham's Natwest Tower and replace it with what will be cityÛªs tallest building....
#
#
# target : 0
# Escape The Heat (and the #ORShow) for a trail run on Desolation Loop you'll be glad you did http://t.co/n2ucNzh38P http://t.co/VU8fWYMw5r...
#
#
# target : 0
# Ended today's staff meeting with the teacher version of 'I Will Survive' #tootrue http://t.co/mCWD37IOF9...
#
#
# target : 1
# Evacuation order lifted for town of Roosevelt - Washington Times http://t.co/Kue48Nmjxh...
#
#
# target : 1
# @SaintRobinho86 someone has to be at the bottom of every league. Tonight clearly demonstrated why the Lions are where they are - sunk!...
#
#
# target : 1
# Water now tops the charts for highest global risk in terms of devastationÛ_ ahead of nuclear war or a global pandemic http://t.co/nbcvbSO9nm...
#
#
# target : 1
# Path of Obliteration
# Back From The Dead
# Story by @KyleWappler @thisishavehope
#
#  http://t.co/1PdNlsP8XW...
#
#
# target : 1
# What tropical storm? #guillermo by hawaiianpaddlesports http://t.co/LgPgAjgomY http://t.co/FKd1mBTB68...
#
#
# target : 1
# #deai #??? #??? #??? Suicide bomber kills 15 in Saudi security site mosque - Reuters  http://t.co/SqydkslFzp...
#
#
# target : 1
# Black Eye 9: A space battle occurred at Star M27329 involving 1 fleets totaling 1236 ships with 7 destroyed...
#
#
# target : 1
# Japan Marks 70th Anniversary of Hiroshima Atomic Bombing http://t.co/3EV07PPaPn...
#
#
# target : 0
# Remaining Sections Of Greystone Psychiatric Hospital Under Demolition
# Pic. 85885473 http://t.co/LzlJZZkCfa...
#
#
# target : 1
# Don't blink ?? won't see the Lightning take the W ?? http://t.co/D4c2iqiRnU...
#
#
# target : 0
# Santa Fe Springs Studebaker Rd / South St **Trfc Collision-No Inj** http://t.co/6uHih9pbrU...
#
#
# target : 0
# @Haley_Whaley Hailstorm Hey There is a Secret Trick to get 375.000 Gems Clash ofClans check them now on my Profile...
#
#
# target : 0
# My hair is poverty at the moment need to get a fade before the weekend gets here...
#
#
# target : 0
# You made my mood go from shitty af to panicking af istg...
#
#
# target : 1
# Deputies: Dog dispute leads to fatal shooting in Person County http://t.co/OazgHoZGYa #gunfail #nra...
#
#
# target : 0
# Juneau Empire - First responders turn out for National Night Out http://t.co/94UYT4ojYK...

# %% [markdown]
# ### 4.4.2 print documents vs target

# %%
def print_sample(sub_df, n_samp=10) : 
    """print out n_samp documents from a corpus"""
    
    if n_samp < len(sub_df): 
        df_samp = sub_df.sample(n_samp)
    else : 
        df_samp = sub_df.copy()
    
    for idx, ser in df_samp.iterrows(): 

        txt_1 = f"target : {ser['target']}\n"
        print(txt_1+ser['text']+ "..." + "\n\n")

# %%
df_1 = df[df.target==1]
df_1.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %%
# print 10 docs of target == 1 

print_sample(df_1)
# Out:
# target : 1
# How many trains derailed that @wmata has to shut down orange/blue in most of DC? The Avengers made less of a mess @unsuckdcmetro...
#
#
# target : 1
# Hurricane 30STM quem lembra...
#
#
# target : 1
# Early wake up call from my sister begging me to come over &amp; ride w/her in the ambulance to the hospital #RODKiai...
#
#
# target : 1
# Death on Railway track: Why rains cannot take all the blame?: Derailment is not very common. Last year less th... http://t.co/jdkQC12tid...
#
#
# target : 1
# Oops.
# H bomb lost 70 miles off the Okinawan coast.
# Fell off the ship 1965.
# http://t.co/yVsJyzwxJR...
#
#
# target : 1
# Solano SR37 / Skaggs Island Rd **Trfc Collision-1141 Enrt** http://t.co/MylIeRUXK1...
#
#
# target : 1
# Nigerian Military Rescue 178 Hostages From Boko Haram - Florida Sentinel Bulletin: Florid... http://t.co/KcTiGYMahl #security #terrorism...
#
#
# target : 1
# Eric Clapton shot the sheriff in 1974 and guess how many people were rioting? Right none....
#
#
# target : 1
# A diamond is just a piece of charcoal that handled stress exceptionally well. We are hard pressed on every side but not crushed.2 cor4:8...
#
#
# target : 1
# Treasures revealed as California drought drains lakes http://t.co/kAH1KmTrj7...

# %%
# print 10 docs of target == 0

print_sample(df[df.target==0])
# Out:
# target : 0
# White Twister Black shift knob M6x1.00 Thread Size http://t.co/SqpshAWs0w http://t.co/udlEbH88uZ...
#
#
# target : 0
# @klavierstuk doesn't so LVG is forced into the market. May beat Spurs and smaller teams with Blind LCB. Top 4/ CL teams will obliterate us....
#
#
# target : 0
# Apollo Brown - Detonate (feat. M.O.P.) by Mello Music Group via #soundcloud https://t.co/PRojeAvG8T...
#
#
# target : 0
# Beastin Tapas this evening with some good folk! #funtimes #demolished http://t.co/JxUEPkmkRh...
#
#
# target : 0
# In my experience if you're always angry and critical as a pundit you are in grave danger of going off the rails. 1/...
#
#
# target : 0
# Smoke it all http://t.co/79upYdCeMp...
#
#
# target : 0
# Ranking #artectura #pop2015 #Nå¼36 Florence + The Machine - Ship To Wreck https://t.co/9LE0B19lVF  #music #playlist #YouTube...
#
#
# target : 0
# If it wasn't for the Blood! ????...
#
#
# target : 0
# Wow Crackdown 3 uses multiple servers in multiplayer?!?! U can destroy whole buildings?!?! #copped...
#
#
# target : 0
# FINALLY a storm...
